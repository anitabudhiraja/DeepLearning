# %% [markdown]
# <a href="https://colab.research.google.com/github/anitabudhiraja/DeepLearning/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_circles
from mlxtend.plotting import plot_decision_regions

# Configuration options
num_samples_total = 1000
training_split = 250
loss_function_used = BinaryCrossentropy()

# Generate data
X, targets = make_circles(n_samples = num_samples_total, factor=0.1)
X_training = X[training_split:, :]
X_testing = X[:training_split, :]
Targets_training = targets[training_split:]
Targets_testing = targets[:training_split]

# Generate scatter plot for training data
plt.scatter(X_training[:,0], X_training[:,1])
plt.title('Nonlinear data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# Set the input shape
feature_vector_shape = len(X_training[0])
input_shape = (feature_vector_shape,)

# Create the model
model = Sequential()
model.add(Dense(12, input_shape=input_shape, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(8, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='sigmoid'))

# Configure the model and start training
model.compile(loss=loss_function_used, optimizer=tensorflow.keras.optimizers.Adam(lr=0.001), metrics=['accuracy'])
history = model.fit(X_training, Targets_training, epochs=30, batch_size=5, verbose=1, validation_split=0.2)

# Test the model after training
test_results = model.evaluate(X_testing, Targets_testing, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')

# Plot decision boundary
plot_decision_regions(X_testing, Targets_testing, clf=model, legend=2)
plt.show()

# Visualize training process
plt.plot(history.history['loss'], label='Binary crossentropy loss (training data)')
plt.plot(history.history['val_loss'], label='Binary crossentropy loss (validation data)')
plt.title('Binary crossentropy loss for circles')
plt.ylabel('Binary crossentropy loss value')
plt.yscale('log')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/30
# 120/120 [==============================] - 1s 3ms/step - loss: 0.6837 - accuracy: 0.5117 - val_loss: 0.6036 - val_accuracy: 0.5267
# Epoch 2/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.8417 - val_loss: 0.4516 - val_accuracy: 1.0000
# Epoch 3/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3705 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 1.0000
# Epoch 4/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 1.0000
# Epoch 5/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.1403 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 1.0000
# Epoch 6/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0789 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 1.0000
# Epoch 7/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 8/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 9/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 10/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 11/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 12/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 13/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 14/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 15/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 16/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 17/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 18/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 19/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 20/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 21/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 22/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 23/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.7751e-04 - val_accuracy: 1.0000
# Epoch 24/30
# 120/120 [==============================] - 0s 1ms/step - loss: 9.3150e-04 - accuracy: 1.0000 - val_loss: 8.6189e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 120/120 [==============================] - 0s 1ms/step - loss: 8.2350e-04 - accuracy: 1.0000 - val_loss: 7.6196e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 120/120 [==============================] - 0s 1ms/step - loss: 7.3077e-04 - accuracy: 1.0000 - val_loss: 6.7804e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 120/120 [==============================] - 0s 1ms/step - loss: 6.5128e-04 - accuracy: 1.0000 - val_loss: 6.0471e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 120/120 [==============================] - 0s 1ms/step - loss: 5.8215e-04 - accuracy: 1.0000 - val_loss: 5.4099e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 120/120 [==============================] - 0s 2ms/step - loss: 5.2190e-04 - accuracy: 1.0000 - val_loss: 4.8600e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 120/120 [==============================] - 0s 1ms/step - loss: 4.6921e-04 - accuracy: 1.0000 - val_loss: 4.3681e-04 - val_accuracy: 1.0000
# 8/8 [==============================] - 0s 2ms/step - loss: 4.3331e-04 - accuracy: 1.0000
# Test results - Loss: 0.00043330586049705744 - Accuracy: 100.0%
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
